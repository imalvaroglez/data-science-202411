# %% [markdown]
# <a href="https://colab.research.google.com/github/imalvaroglez/data-science-202411/blob/main/2_Construcci%C3%B3n_de_modelos_de_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src ='https://www.researchgate.net/publication/351733662/figure/fig1/AS:11431281117189725@1675396236058/Classification-of-machine-learning-algorithms.png'>

# %% [markdown]
# # **CONSTRUCCIÓN DE MODELOS**

# %% [markdown]
# <img src ='https://ml-ops.org/img/ml-engineering.jpg' width = 500>
#
# https://ml-ops.org/content/end-to-end-ml-workflow

# %% [markdown]
# ![ModelBuilding.png](data:image/png;base64,...)

# %% [markdown]
# #Construcción modelos con sklearn
#
# <img src = "https://pypi-camo.freetls.fastly.net/b86b2758380b6bc7cbdf4ff97fda9826a3b74aa2/68747470733a2f2f7261772e67697468756275736572636f6e74656e742e636f6d2f7363696b69742d6c6561726e2f7363696b69742d6c6561726e2f6d61696e2f646f632f6c6f676f732f7363696b69742d6c6561726e2d6c6f676f2e706e67">
#
# La librería **scikit-learn** contiene muchos modelos, se acostumbra nombrarla como **sklearn**. <p>
# Es muy sencilla y popular para modelar datos almacenados como DataFrames.
#
#
# Los pasos para construir un modelo son:
#
#
# *   Definir el tipo de modelo y sus parámetros
# *   Entrenar, capturar patrones de los datos
# *   Predecir
# *   Evaluar, determinar qué tan apropiada es la predicción
#
# Información: https://scikit-learn.org/stable/

# %% [markdown]
# Scikit permite tareas como:
#
# * Clasificación
# * Regresión
# * Clustering
# * Reducción de dimensionalidad
# * Procesamiento de datos
#
# Además es compatible con Numpy y Pandas

# %% [markdown]
# **Patrón general**
#
# * transform(): Modifica datos (para preprocesamiento).
# * fit(): Entrena el modelo.
# * fit_transform(): Combina fit() y transform().
# * predict(): Realiza predicciones.
# * score(): Evalúa el modelo.

# %% [markdown]
# **Preprocesamiento de Datos**
#
# Transformadores comunes:
# * StandardScaler (escalado de datos).
# * MinMaxScaler (normalización).
# * LabelEncoder y OneHotEncoder (codificación de variables categóricas).

# %% [markdown]
# **Selección de modelos**
#
# * Clasificación: Ejemplo con LogisticRegression, RandomForestClassifier, SVC.
# * Regresión: Ejemplo con LinearRegression, Ridge, SVR.
# * Clustering: Ejemplo con KMeans, DBSCAN.
# * Reducción de dimensionalidad: Uso de PCA.

# %% [markdown]
# **División de datos**
#
# * Importancia de separar datos en conjuntos de entrenamiento y prueba.
# * Uso de `train_test_split`.

# %% [markdown]
# **Evaluación de modelos**
#
# Métricas:
#
# Importancia de seleccionar métricas apropiadas según la tarea.
# * Clasificación: accuracy_score, confusion_matrix, classification_report.
# * Regresión: mean_squared_error, r2_score.

# %% [markdown]
# **Hiperparámetros y Optimización**
#
# * Cómo ajustar modelos para mejorar el rendimiento.
# * Grid Search (`GridSearchCV`) y Random Search (`RandomizedSearchCV`).

# %% [markdown]
# ## Métricas
#
# Los modelos deben evaluarse para asegurar su precisión y confiabilidad. Una herramienta muy utilizada es la matriz de confusión.
#
# La matriz de confusión resume la eficiencia del modelo sobre el conjunto de prueba, indicando las instancias predecidas correctamente y las que no:
#
# * True Positive (TP): El modelo predijo correctamente una salida positiva
# * True Negative (TN): El modelo predijo correctamente una salida negativa
# * False Positive (FP): El modelo predijo incorrectamente una salida positiva
# * False Negative (FN): El modelo predijo incorrectamente una salida negativa
#
#
# <img src = 'https://cdn.prod.website-files.com/660ef16a9e0687d9cc27474a/662c42677529a0f4e97e4f96_644aea65cefe35380f198a5a_class_guide_cm08.png'>

# %% [markdown]
# <img src = 'https://pbs.twimg.com/media/E1gLaVKXsAIRMUi.jpg:large'>

# %% [markdown]
# ## **Métricas basadas en los datos de la Matriz de confusión**
#
# El ***accuracy*** es una de varias métricas que se usan para medir el éxito de un problema de clasificación. Es la relación entre las predicciones correctas y el total de predicciones: `accuracy = númeroCorrecto / total`.  Un modelo que siempre predice correctamente debería tener un accuracy de `1.0`. Se usa cuando las clases en el dataset ocurren con igual frecuencia.
#
# <img src = 'https://images.datacamp.com/image/upload/v1701364260/image_d6ced554a1.png'>

# %% [markdown]
# Si se tienen más características:
#
# <img src = 'https://media.geeksforgeeks.org/wp-content/uploads/20240708132251/confusion-Matrix.PNG'>
